# %% [markdown]
# <h1 style="text-align:center">Deep Learning  Lab Session </h1>
# <h1 style="text-align:center">First Lab Session - 1.5 Hour </h1>
# <h1 style="text-align:center">Artificial Neural Networks for Handwritten Digits Recognition</h1>

# %% [markdown]
# <b> Student 1:</b> Nélida MIRABET HERRANZ
# <b> Student 2:</b> Sylwia ENGLOT
#
#
# The aim of this session is to practice with Artificial Neural Networks. Answers and experiments should be made by groups of two students. Each group should fill and run appropriate notebook cells.
#
# Follow instructions step by step until the end and submit your complete notebook as an archive (tar -cf groupXnotebook.tar DL_lab1/).
# Do not forget to run all your cells before generating your final report and do not forget to include the names of all participants in the group. The lab session should be completed by March 20th 2019.

# %% [markdown]
# # Introduction

# %% [markdown]
# During this lab session, you will implement, train and test a Neural Network
# for the Handwritten Digits Recognition problem <a href="http://yann.lecun.com/exdb/mnist/"> [1] </a> with  different settings of hyperparameters. You will use the MNIST dataset which was constructed from scanned documents available from the National Institute of Standards and Technology (NIST). Images of digits were taken from a variety of scanned documents, normalized in size and centered.
#
#
# <img src="Nimages/mnist.png" width="350" height="500" align="center">
# <center><span>Figure 1: MNIST digits examples</span></center>
#
#
# This assignment includes a written part of programms to help you understand how to build and train
# your neural net and then to test your code and get results.
#
# 1. <a href="NeuralNetwork.py"> NeuralNetwork.py </a>
# 2. <a href="transfer_functions.py"> transfer_functions.py </a>
# 3.  <a href="utils.py "> utils.py </a>
#
#
# Functions defined inside the python files mentionned above can be imported  using the python command "from filename import function".
#
# You will use the following libraries:
#
# 1. <a href="http://cs231n.github.io/python-numpy-tutorial/"> numpy </a>: for creating arrays and using methods to manipulate arrays;
#
# 2. <a href="http://matplotlib.org/"> matplotlib  </a>: for making plots.
#
# Before starting the lab, please launch the cell below. After that, you may not need to do any imports during the lab.

# %%
# All imports
from NeuralNetwork import NeuralNetwork
from transfer_functions import *
from utils import *
import numpy as np
import matplotlib

# %% [markdown]
# # Section 1 :  Your First Neural Network
#
# <b>Part 1</b>: Before designing and writing your code, you will first work on a neural network by hand.
# Consider the following neural network with two inputs $x=(x_1,x_2)$, one hidden layer and a single output unit $y$.
# The initial weights are set to random values. Neurons 6 and 7 represent biases. Bias values are equal to 1. You will consider a training sample whose feature vector is $x = (0.8, 0.2)$ and whose label is $y = 0.4$.
#
# Assume that neurons have a sigmoid activation function  $f(x)=\frac{1}{(1+e^{-x})}$. The loss function $L$ is a Mean Squared Error (MSE): if $o$ denotes the output of the neural network, then the loss for a given sample $(o, y)$ is $L(o, y) = \left|\left| o - y \right|\right|^2$. In the following, you will assume that if you want to backpropagate the error on a whole batch, you will backpropagate the average error on that batch. More formally, let $((x^{(1)}, y^{(1)}), ..., (x^{(N)}, y^{(N)}))$ be a batch and $o^{(k)}$ the output associated to $x^{(k)}$. Then the total error $\bar{L}$ will be as follows:
#
# <div align="center">$\bar{L} = \frac{1}{N} \sum_{k=1}^{N} L(o^{(k)}, y^{(k)})$.</div>
#
#
#
#
# <img src="Nimages/NN.png" width="700" height="900">
# <center><span>Figure 2: Neural network </span></center>
#
#
# <b>Question 1.1.1</b>: Compute the new values of weights $w_{i,j}$ after a forward pass and a backward pass, and the outputs of the neural network before and after the backward path, when the learning rate is $\lambda$=5.
# $w_{i,j}$ is the weight of the connexion between neuron $i$ and neuron $j$. Please detail your computations in the cell below and print your answers.

# %%
lr = 5.0
x1, x2 = 0.8, 0.2
w1_01, w1_11, w1_21, w1_02, w1_12, w1_22 = 0.2, 0.3, 0.8, -0.4, -0.5, 0.2
w2_01, w2_11, w2_21 = 0.5, -0.6, 0.4
y = 0.4

o1_1 = sigmoid(x1 * w1_11 + x2 * w1_21 + w1_01)     # Output of the green neuron
o1_2 = sigmoid(x1 * w1_12 + x2 * w1_22 + w1_02)     # Output of the green neuron
o2_1 = sigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) # Output of the black neuron


print("=== FORWARD PASS 1 ===")
print("o =", o2_1)

# Partial derivatives of the loss wrt weights of the second layer
dL_w2_01 = 2*(o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01)
dL_w2_11 = 2*(o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * o1_1
dL_w2_21 = 2*(o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * o1_2
print(dL_w2_01, dL_w2_11, dL_w2_21)

# Partial derivatives of the loss wrt weights of the first layer
dL_w1_01 = 2*((o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * w2_11) * dsigmoid(x1 * w1_11 + x2 * w1_21 + w1_01)
dL_w1_11 = 2*((o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * w2_11) * dsigmoid(x1 * w1_11 + x2 * w1_21 + w1_01) * x1
dL_w1_21 = 2*((o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * w2_11) * dsigmoid(x1 * w1_11 + x2 * w1_21 + w1_01) * x2
dL_w1_02 = 2*((o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * w2_21) * dsigmoid(x1 * w1_12 + x2 * w1_22 + w1_02)
dL_w1_12 = 2*((o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * w2_21) * dsigmoid(x1 * w1_12 + x2 * w1_22 + w1_02) * x1
dL_w1_22 = 2*((o2_1 - y) * dsigmoid(o1_1 * w2_11 + o1_2 * w2_21 + w2_01) * w2_21) * dsigmoid(x1 * w1_12 + x2 * w1_22 + w1_02) * x2

# Weights updates
w1_01 -= lr*dL_w1_01
w1_11 -= lr*dL_w1_11
w1_21 -= lr*dL_w1_21
w1_02 -= lr*dL_w1_02
w1_12 -= lr*dL_w1_12
w1_22 -= lr*dL_w1_22
w2_01 -= lr*dL_w2_01
w2_11 -= lr*dL_w2_11
w2_21 -= lr*dL_w2_21

print("=== BACKWARD PASS ===")
print("w1_01 =", w1_01)
print("w1_11 =", w1_11)
print("w1_21 =", w1_21)
print("w1_02 =", w1_02)
print("w1_12 =", w1_12)
print("w1_22 =", w1_22)
print("w2_01 =", w2_01)
print("w2_11 =", w2_11)
print("w2_21 =", w2_21)

o1_1 = sigmoid(x1*w1_11 + x2*w1_21 + w1_01)
o1_2 = sigmoid(x1*w1_12 + x2*w1_22 + w1_02)
o2_1 = sigmoid(o1_1*w2_11 + o1_2*w2_21 + w2_01)

print("=== FORWARD PASS 2 ===")
print("o =", o2_1)
# Out:
# === FORWARD PASS 1 ===
# o = 0.5597295991095776
# 0.07872508892961443 0.05082935012559211 0.025085455644548556
# === BACKWARD PASS ===
# w1_01 = 0.2540331790269339
# w1_11 = 0.3432265432215471
# w1_21 = 0.8108066358053868
# w1_02 = -0.4341841377344243
# w1_12 = -0.5273473101875394
# w1_22 = 0.19316317245311515
# w2_01 = 0.10637455535192786
# w2_11 = -0.8541467506279605
# w2_21 = 0.2745727217772572
# === FORWARD PASS 2 ===
# o = 0.40648823589210104

# %% [markdown]
# <b>Part 2</b>: Neural Network Implementation
#
# In Part 1, you computed weight updates for one sample. This is what we do for the stochastic gradient descent algorithm. However in the rest of the lab, you will be to implement the batch version of the gradient descent.
#
# Please read all source files carefully and understand the data structures and all functions.
# You are to complete the missing code.
# First you should define the neural network (using the NeuralNetwork class, see in the <a href="NeuralNetwork.py"> NeuralNetwork.py</a> file) and reinitialise weights.
# Then you will need to complete the feedforward() and the backpropagate() functions.
#
# <b>Question 1.2.1</b>: Implement the feedforward() function.

# %%
class NeuralNetwork(NeuralNetwork):
    def feedforward(self, inputs):
        transfer_f = self.transfer_f
        inputs = [x + [1.] for x in inputs]
        self.input = np.array(inputs) # Shape = [batch_size, number_of_input_values+1]
        u_1 = np.dot(inputs, self.W_input_to_hidden )# Compute activations for the hidden layer
              # Shape of u_1 should be [batch_size, number_of_neurons_in_hidden_layer]
        self.u_hidden = u_1
        self.o_hidden = np.ones((u_1.shape[0], u_1.shape[1]+1)) # Shape = [batch_size, number_of_hidden_values+1]
        self.o_hidden[:,:-1] = transfer_f(u_1) # Compute output of hidden layer
        u_2 = np.dot(self.o_hidden, self.W_hidden_to_output) # Compute activations for the output layer
        self.u_output = u_2
        self.o_output = transfer_f(u_2) # Compute output of output layer

# %% [markdown]
# <b>Question 1.2.2</b>: Test your implementation: create the Neural Network defined in Part 1 and see if the feedforward() function you implemented gives the same results as the ones you found by hand.

# %%
# First define your neural network
model = NeuralNetwork(2,2,1)

# Then initialize the weights according to Figure 2
W_input_to_hidden = np.array([[0.3, -0.5], [0.8, 0.2], [0.2, -0.4]])
W_hidden_to_output = np.array([[-0.6], [0.4], [0.5]])
model.weights_init(W_input_to_hidden, W_hidden_to_output)

# Feed test values
test = [[0.8, 0.2]]
model.feedforward(test)

# Print the output
print("Output =", model.o_output[0,0])
# Out:
# Output = 0.5597295991095776

# %% [markdown]
# <b>Question 1.2.3</b>: Implement the backpropagate() function.

# %%
class NeuralNetwork(NeuralNetwork):
    def backpropagate(self, targets, learning_rate=5.0):
        transfer_df = self.transfer_df
        l = learning_rate
        targets = np.array(targets) # Target outputs

        self.dL_du_output = (self.o_output - targets) * transfer_df(self.u_output) # Compute partial derivative of loss with respect to activations of output layer
        activ = np.transpose(np.array(self.u_hidden))
        self.dL_du_hidden = np.dot(self.dL_du_output, np.transpose(self.W_hidden_to_output[:-1])) # Compute partial derivative of loss with respect to activations of hidden layer
        self.dL_du_hidden = np.multiply( np.transpose(self.dL_du_hidden), transfer_df(activ))
        # Compute partial derivative of loss with respect to weights 
        dW_input_to_hidden = 2*np.dot(self.dL_du_hidden, self.input)
        dW_hidden_to_output = 2*np.dot(np.transpose(self.dL_du_output), self.o_hidden)
        
        # Make updates
        self.W_hidden_to_output -= l*np.transpose(dW_hidden_to_output)/len(targets)
        self.W_input_to_hidden -= l*np.transpose(dW_input_to_hidden)/len(targets)

# %% [markdown]
# <b>Question 1.2.4</b>: Test your implementation: create the Neural Network defined in Part 1 and see if the backpropagate() function you implemented gives the same weight updates as the ones you found by hand. Do another forward pass and see if the new output is the same as the one you obtained in Question 1.1.1.

# %%
# First define your neural network
model = NeuralNetwork(2,2,1)

# Then initialize the weights according to Figure 2
W_input_to_hidden = np.array([[0.3, -0.5], [0.8, 0.2], [0.2, -0.4]])
W_hidden_to_output = np.array([[-0.6], [0.4], [0.5]])
model.weights_init(W_input_to_hidden, W_hidden_to_output)

# Feed test values
test = [[0.8, 0.2]]
model.feedforward(test)

# Backpropagate
targets = [[0.4]]
model.backpropagate(targets)

# Print weights
print("W_input_to_hidden =", model.W_input_to_hidden)
print("W_hidden_to_output =", model.W_hidden_to_output)

# Feed test values again
model.feedforward(test)

# Print the output
print("Output =", model.o_output)
# Out:
# W_input_to_hidden = [[ 0.34322654 -0.52734731]
#  [ 0.81080664  0.19316317]
#  [ 0.25403318 -0.43418414]]
# W_hidden_to_output = [[-0.85414675]
#  [ 0.27457272]
#  [ 0.10637456]]
# Output = [[0.40648824]]

# %% [markdown]
# Checked your implementations and found that everything was fine? Congratulations! You can move to the next section.

# %% [markdown]
# # Section 2: Handwritten Digits Recognition

# %% [markdown]
# The MNIST dataset consists of handwritten digit images. It is split into a training set containing 60,000 samples and a test set containing 10,000 samples. In this Lab Session, the official training set of 60,000 images is divided into an actual training set of 50,000 samples a validation set of 10,000 samples. All digit images have been size-normalized and centered in a fixed size image of 28 x 28 pixels. Images are stored in byte form: you will use the NumPy python library to convert data files into NumPy arrays that you will use to train your Neural Networks.
#
# You will first work with a small subset of MNIST (1000 samples), then on a very small subset of MNIST (10 samples), and eventually run a model on the whole one.
#
# The MNIST dataset is available in the Data folder.
# To get the training, testing and validation data, run the load_data() function.

# %%
# Just run that cell ;-)
training_data, validation_data, test_data = load_data()
small_training_data = (training_data[0][:1000], training_data[1][:1000])
small_validation_data = (validation_data[0][:200], validation_data[1][:200])
indices = [1, 3, 5, 7, 2, 0, 13, 15, 17, 4]
vsmall_training_data = ([training_data[0][i] for i in indices], [training_data[1][i] for i in indices])
# Out:
# Loading MNIST data .....
# Done.

# %%
# And you can run that cell if you want to see what the MNIST dataset looks like
ROW = 2
COLUMN = 5
for i in range(ROW * COLUMN):
    # train[i][0] is i-th image data with size 28x28
    image = np.array(training_data[0][i]).reshape(28, 28)   
    plt.subplot(ROW, COLUMN, i+1)          
    plt.imshow(image, cmap='gray')  # cmap='gray' is for black and white picture.
plt.axis('off')  # do not show axis value
plt.tight_layout()   # automatic padding between subplots
plt.show()

# %% [markdown]
# <b>Part 1</b>: Build a bigger Neural Network
#
# The input layer of the neural network that you will build contains neurons encoding the values of the input pixels. The training data for the network will consist of many 28 by 28 pixel images of scanned handwritten digits. Thus, the input layer contains 784=28×28 units. The second layer of the network is a hidden layer. We set the number of neurons in the hidden layer to 30. The output layer contains 10 neurons.
#
# <b>Question 2.1.1</b>: Create the network described above using the NeuralNetwork class.

# %%
# Define your neural network
mnist_model = NeuralNetwork(784,30,10)

# %% [markdown]
# <b>Question 2.1.2</b>: Train your Neural Network on the small subset of MNIST (300 iterations) and print the new accuracy on test data. You will use small_validation_data for validation. Try different learning rates (0.1, 1.0, 10.0). You should use the train() function of the NeuralNetwork class to train your network, and the weights_init() function to reinitialize weights between tests. Print the accuracy of each model on test data using the predict() function.

# %%
# Train NN and print accuracy on test data
print('Model: 30 hidden layerr')
print('CHECKING IMPACT OF DIFFERENT LEARNING RATES:')
print('--------------------------------------------\n')
# Learning rate 0.1
print('Learning rate 0.1:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples in test data evaluated correctly:\n', mnist_model.predict(test_data))
# Learning rate 1
print('Learning rate 1:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:\n', mnist_model.predict(test_data))
# Learning rate 10.
print('Learning rate 10:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data))
# Out:
# Model: 30 hidden layerr
# CHECKING IMPACT OF DIFFERENT LEARNING RATES:
# --------------------------------------------
#
#
# Learning rate 0.1:
# Training time: 88.2290735244751
# Number of examples in test data evaluated correctly: 1439
#
# Learning rate 1:
# Training time: 94.43110990524292
# Number of examples in test data evaluated correctly: 8270
#
# Learning rate 10:
# Training time: 140.84333062171936
# Number of examples in test data evaluated correctly: 1028

# %% [markdown]
# <b>Question 2.1.3</b>: Do the same with 15 and 75 hidden neurons.

# %%
# Define your neural network
print('CHECKING IMPACT OF DIFFERENT NUMBERS OF HIDDEN NEURONS:')
print('-------------------------------------------------------\n')
# 15 hidden neurons 
print('###  15 HIDDEN NEURONS ###:')
mnist_model = NeuralNetwork(784,15,10)
# Learning rate 0.1
print('Learning rate 0.1:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 1.
print('Learning rate 1')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 10.
print('Learning rate 10:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n\n')

# 75 hidden neurons
print('###  75 HIDDEN NEURONS ###:')
mnist_model = NeuralNetwork(784,75,10)
# Learning rate 0.1
print('')
print('Learning rate 0.1:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 1.
print('')
print('Learning rate 1:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 10.
print('')
print('Learning rate 10:')
mnist_model.weights_init()
mnist_model.train(small_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Out:
# CHECKING IMPACT OF DIFFERENT NUMBERS OF HIDDEN NEURONS:
# -------------------------------------------------------
#
# ###  15 HIDDEN NEURONS ###:
# Learning rate 0.1:
# Training time: 83.98383593559265
# Number of examples in test data evaluated correctly: 1201
#
# Learning rate 1
# Training time: 95.97117280960083
# Number of examples in test data evaluated correctly: 7513
#
# Learning rate 10:
# Training time: 98.73682022094727
# Number of examples in test data evaluated correctly: 1028
#
#
# ###  75 HIDDEN NEURONS ###:
#
# Learning rate 0.1:
# Training time: 137.3187267780304
# Number of examples in test data evaluated correctly: 2428
#
#
# Learning rate 1:
# Training time: 131.46328616142273
# Number of examples in test data evaluated correctly: 8516
#
#
# Learning rate 10:
# Training time: 163.9961700439453
# Number of examples in test data evaluated correctly: 4866

# %% [markdown]
# <b>Question 2.1.4</b>: Repeat Questions 2.1.2 and 2.1.3 on the very small datasets. You will use small_validation_data for validation.

# %%
# Train NN and print accuracy on test data
print('CHECKING IMPACT OF SMALL DATASET:')
print('---------------------------------\n')
# 30 hidden neurons
print('###  30 HIDDEN NEURONS ###:\n')
mnist_model = NeuralNetwork(784,30,10)
# Learning rate 0.1
print('Learning rate 0.1:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 1.
print('Learning rate 1:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 10.
print('Learning rate 10:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n\n')

# 15 hidden neurons
print('###  15 HIDDEN NEURONS ###:\n')
mnist_model = NeuralNetwork(784,15,10)
# Learning rate 0.1
print('Learning rate 0.1:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 1.
print('Learning rate 1:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 10.
print('Learning rate 10:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n\n')

# 75 hidden neurons
print('###  75 HIDDEN NEURONS ###:\n')
mnist_model = NeuralNetwork(784,75,10)
# Learning rate 0.1
print('Learning rate 0.1:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 1.
print('Learning rate 1:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Learning rate 10.
print('Learning rate 10:')
mnist_model.weights_init()
mnist_model.train(vsmall_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data),'\n')
# Out:
# CHECKING IMPACT OF SMALL DATASET:
# ---------------------------------
#
# ###  30 HIDDEN NEURONS ###:
#
# Learning rate 0.1:
# Training time: 9.784518241882324
# Number of examples in test data evaluated correctly: 2283
#
# Learning rate 1:
# Training time: 9.257038593292236
# Number of examples in test data evaluated correctly: 5008
#
# Learning rate 10:
# Training time: 9.019021987915039
# Number of examples in test data evaluated correctly: 964
#
#
# ###  15 HIDDEN NEURONS ###:
#
# Learning rate 0.1:
# Training time: 17.399974822998047
# Number of examples in test data evaluated correctly: 1702
#
# Learning rate 1:
# Training time: 17.51221799850464
# Number of examples in test data evaluated correctly: 5035
#
# Learning rate 10:
# Training time: 18.417837381362915
# Number of examples in test data evaluated correctly: 1055
#
#
# ###  75 HIDDEN NEURONS ###:
#
# Learning rate 0.1:
# Training time: 18.82684874534607
# Number of examples in test data evaluated correctly: 3653
#
# Learning rate 1:
# Training time: 16.49990940093994
# Number of examples in test data evaluated correctly: 5132
#
# Learning rate 10:
# Training time: 16.6914644241333
# Number of examples in test data evaluated correctly: 4050

# %% [markdown]
# <b>Question 2.1.5</b>: Explain the results you obtained at Questions 2.1.2, 2.1.3 and 2.1.4.

# %% [markdown]
# In the previous graphics we can see a relation between the number of iterations in the trainning process and the accuracy of the model. The blue curve describes the accuracy of the model in the validation data while the orange curve describes the accuracy of the model in the test data.
# Here we can distinguish 3 important paramenter that affect to the accuracy of the model in the test data: Learning rate, number of hidden neurons and size of training set.
#
# <b>LEARNING RATE:</b> If we choose a small learning rate ($\lambda=0.1$) we have a slow learning, we might need many itetations to converge and this convergence could be to a local minima. As we can see in the different plots, the accuracy is very low, less than 20%. Even if the number of iterations increases the accuracy does not increase (in some cases is even lower).
# If we choose a high learning rate ($\lambda=10$), then we can step over the minimum and fail to converge. As we can see in the graphics just in the case of 75 hidden neurons we can have one valid result but we see how easy is to miss one minimum due to the big learning rate.
# For a intermediate learning rate ($\lambda=1$), we can see in all the cases a good accuracy of the model on the test data, is always over 70%.
#
# <b>NUM. HIDDEN NEURONS:</b> We see that if we increase the number of hidden neurons the accuracy on test data is higher with a small number of iterations. With 15 hidden neurons we have poor accuracy due to the size of the data set but we can have a good performance with 30 or 75 hidden neurons.
#
# <b>SIZE TRAINNING SET:</b> The size of the trainning set is also very important, with a smaill training set, in any the the accuracy on the test data is higher than 50% and there is a high risk of overfitting as we increase the number of iterations. So the higher the training test, the less posibilities of ovefitting we have.

# %% [markdown]
# <b>Question 2.1.6</b>: Among all the numbers of hidden neurons and learning rates you tried in previous questions, which ones would you expect to achieve best performances on the whole dataset? Justify your answer.

# %% [markdown]
# In order to be consistent with the analysis done before, we can choose the learning rate as $\lambda=1$ and as we said before either 30 or 75 hidden neurons could be good. Probably, because now we have a bigger dataset, 75 could perform better but we will try to run for 30 and 75 just to be sure.
#
# -------------------------------------------------
#
# As we can see in the following exercise, with both, 30 and 75 iterations can have 90% of accuracy. The only difference is, as we expected, that we can have less accuracy with less iterations with 75 hidden layers.

# %% [markdown]
# <b>Question 2.1.7</b>: Train a model with the number of hidden neurons and the learning rate you chose in Question 2.1.6 and print its accuracy on the test set. You will use validation_data for validation. Training can be long on the whole dataset (~40 minutes): we suggest that you work on the optional part while waiting for the training to finish.

# %% [markdown]
# mnist_model = mnist_model = NeuralNetwork(784,75,10)
# mnist_model.weights_init()
# mnist_model.train(training_data, validation_data, iterations=300, learning_rate=1)
# mnist_model.predict(test_data)

# %%
print('')
print('30 hidden layer:')
mnist_model = mnist_model = NeuralNetwork(784,30,10)
mnist_model.weights_init()
mnist_model.train(training_data, validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data))

print('')
print('75 hidden layer:')
mnist_model = mnist_model = NeuralNetwork(784,75,10)
mnist_model.weights_init()
mnist_model.train(training_data, validation_data, iterations=300, learning_rate=1)
print('Number of examples in test data evaluated correctly:', mnist_model.predict(test_data))
# Out:
# 30 hidden layer:
# Training time: 2138.8108184337616
# Number of examples in test data evaluated correctly: 8513
#
# 75 hidden layer:
# Training time: 2291.5326204299927
# Number of examples in test data evaluated correctly: 8841

# %% [markdown]
# <b>Part 2 (optional)</b>: Another loss function
#
# In classification problems, we usually replace the sigmoids in the output layer by a "softmax" function and the MSE loss by a "cross-entropy" loss. More formally, let $u = (u_1, ..., u_n)$ be the vector representing the activation of the output layer of a Neural Network. The output of that neural network is $o = (o_1, ..., o_n) = \textrm{softmax}(u)$, and
#
# <div align="center">$\textrm{softmax}(u) = (\frac{e^{u_1}}{\sum_{k=1}^n e^{u_k}}, ..., \frac{e^{u_n}}{\sum_{k=1}^n e^{u_k}})$.</div>
#
# If $t = (t_1, ..., t_n)$ is a vector of non-negative targets such that $\sum_{k=1}^n t_k = 1$ (which is the case in classification problems, where one target is equal to 1 and all others are equal to 0), then the cross-entropy loss is defined as follows:
#
# <div align="center">$L_{xe}(o, t) = - \sum_{k=1}^n t_k\log(o_k)$.</div>
#
# <b>Question 2.2.1</b>: Let $L_{xe}$ be the cross-entropy loss function and $u_i$, $i \in \lbrace 1, ..., n \rbrace$, be the activations of the output neurons. Let us assume that the transfer function of the output neurons is the softmax function. Targets are $t_1, ..., t_n$. Derive a formula for $\frac{\partial L_{xe}}{\partial u_i}$ (details of your calculations are not required).

# %% [markdown]
# Answer: $\frac{\partial L_{xe}}{\partial u_i} = \frac{e^{u_{i}}}{\sum^{n}_{k=1}e^{u_{k}}}-t_{i}$

# %% [markdown]
# <b>Question 2.2.2</b>: Implement a new feedforward() function and a new backpropagate() function adapted to the cross-entropy loss instead of the MSE loss.

# %%
class NeuralNetwork(NeuralNetwork):
    def feedforward_xe(self, inputs):
        transfer_f = self.transfer_f
        inputs = [x + [1.] for x in inputs]
        self.input = np.array(inputs) # Shape = [batch_size, number_of_input_values+1]
        u_1 = np.dot(inputs, self.W_input_to_hidden )# Compute activations for the hidden layer
              # Shape of u_1 should be [batch_size, number_of_neurons_in_hidden_layer]
        self.u_hidden = u_1
        self.o_hidden = np.ones((u_1.shape[0], u_1.shape[1]+1)) # Shape = [batch_size, number_of_hidden_values+1]
        self.o_hidden[:,:-1] = transfer_f(u_1) # Compute output of hidden layer
        u_2 = np.dot(self.o_hidden, self.W_hidden_to_output) # Compute activations for the output layer
        self.u_output = u_2
        self.o_output = softmax(u_2) # Compute output of output layer
        pass

    def backpropagate_xe(self, targets, learning_rate=5.0):
        transfer_df = self.transfer_df
        l = learning_rate
        targets = np.array(targets) # Target outputs
        
        self.dL_du_output = softmax(self.u_output) - targets # Compute partial derivative of loss with respect to activations of output layer
        activ = np.transpose(np.array(self.u_hidden))
        self.dL_du_hidden = np.dot(self.dL_du_output, np.transpose(self.W_hidden_to_output[:-1])) # Compute partial derivative of loss with respect to activations of hidden layer
        self.dL_du_hidden = np.multiply( np.transpose(self.dL_du_hidden), transfer_df(activ))
        # Compute partial derivative of loss with respect to weights 
        dW_input_to_hidden = 2*np.dot(self.dL_du_hidden, self.input)
        dW_hidden_to_output = 2*np.dot(np.transpose(self.dL_du_output), self.o_hidden)
        
        # Make updates
        self.W_hidden_to_output -= l*np.transpose(dW_hidden_to_output)/len(targets)
        self.W_input_to_hidden -= l*np.transpose(dW_input_to_hidden)/len(targets)
        pass

# %% [markdown]
# <b>Question 2.2.3</b>: Create a new Neural Network with the same architecture as in Question 2.1.1 and train it using the softmax cross-entropy loss.

# %%
# Define your neural network
mnist_model_xe = NeuralNetwork(784,30,10)

# Train NN and print accuracy on validation data
# Learning rate 0.1
print('')
print('Learning rate 0.1:')
mnist_model_xe.weights_init()
mnist_model_xe.train(small_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples evaluated correctly:', mnist_model_xe.predict(validation_data))
# Learning rate 1
print('')
print('Learning rate 1:')
mnist_model_xe.weights_init()
mnist_model_xe.train(small_training_data, small_validation_data, iterations=300, learning_rate=1)
print('Number of examples evaluated correctly:', mnist_model_xe.predict(validation_data))
# Learning rate 10.
print('')
print('Learning rate 10:')
mnist_model_xe.weights_init()
mnist_model_xe.train(small_training_data, small_validation_data, iterations=300, learning_rate=10)
print('Number of examples evaluated correctly:', mnist_model_xe.predict(validation_data))
# Out:
# Learning rate 0.1:
# Training time: 31.652818202972412
# Number of examples evaluated correctly: 1803
#
# Learning rate 1:
# Training time: 31.927297353744507
# Number of examples evaluated correctly: 8483
#
# Learning rate 10:
# Training time: 31.93661904335022
# Number of examples evaluated correctly: 1090

# %%
# Print accuracy on test data
# Learning rate 0.1
print('')
print('Learning rate 0.1:')
mnist_model_xe.weights_init()
mnist_model_xe.train(small_training_data, small_validation_data, iterations=300, learning_rate=0.1)
print('Number of examples evaluated correctly:')
mnist_model_xe.predict(test_data)
# Learning rate 1
print('')
print('Learning rate 1:')
mnist_model_xe.weights_init()
mnist_model_xe.train(small_training_data, small_validation_data, iterations=300, learning_rate=1)
mnist_model_xe.predict(test_data)
print('Number of examples evaluated correctly:')
# Learning rate 10.
print('')
print('Learning rate 10:')
mnist_model_xe.weights_init()
mnist_model_xe.train(small_training_data, small_validation_data, iterations=300, learning_rate=10)
mnist_model_xe.predict(test_data)
print('Number of examples evaluated correctly:')
# Out:
# Learning rate 0.1:
# Training time: 32.05180048942566
# Number of examples evaluated correctly:
#
# Learning rate 1:
# Training time: 31.945032835006714
# Number of examples evaluated correctly:
#
# Learning rate 10:
# Training time: 31.831137657165527
# Number of examples evaluated correctly:

# %% [markdown]
# <b>Question 2.2.4</b>: Compare your results with the MSE loss and with the cross-entropy loss.

# %% [markdown]
# If we compate the plots of exercise 2.1.2 (using MSE loss) and exercise 2.2.3 (using cross-entropy loss) we can see that for a learning rate of $\lambda = 10$ the result is poor. Also, for $\lambda = 0.1$ even if with cross-entropy loss the accuracy on test data is 5% higher, the results are not good.
#
# But if we compare the plots with $\lambda = 1$ we see more or less the same performance, the accuracy of the model in the test data behaves in the same way using both, MSE loss and cross-entropy loss, both arriving to a accuracy of 80% in the 300th iteration.

# %% [markdown]
# <div align="center"><b>THE END!</b>
